# %% [markdown]
# <h1> Python API Homework </h1>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from config import api_key
from citipy import citipy
import openweathermapy.core as owm

# %%
output_file_path=os.path.join('output','cities.csv')
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = (citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name).title()
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

if len(cities)<500:
    # Create a set of random lat and lng combinations
    lats = np.random.uniform(low=-90.000, high=90.000, size=1000)
    lngs = np.random.uniform(low=-180.000, high=180.000, size=1000)
    lat_lngs = zip(lats, lngs)

#     Identify nearest city for each lat, lng combination
    for lat_lng in lat_lngs:
        city = (citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name).title()

        # If the city is unique, then add it to a our cities list
        if city not in cities:
            cities.append(city)
print(len(cities))
# Out:
# 436
# 724

# %%
#settings for owm
settings={'units':'imperial','appid':api_key}
iteration=0
temp=[]
lat=[]
humid=[]
cloud=[]
wind=[]
#iterate through dataframe and update with relevant data
for city in cities:
    print(f"Retriving data for Index {iteration}: {city}.")
    try:
        current_weather = owm.get_current(city, **settings)
        temp.append(current_weather['main']['temp'])
        lat.append(current_weather['coord']['lat'])
        humid.append(current_weather['main']['humidity'])
        cloud.append(current_weather['clouds']['all'])
        wind.append(current_weather['wind']['speed'])
    except:
        print('Data missing. Skipping')
        temp.append(np.nan)
        lat.append(np.nan)
        humid.append(np.nan)
        cloud.append(np.nan)
        wind.append(np.nan)  
        
    print("----------")
    iteration=iteration+1
# Out:
# Retriving data for Index 0: Constitucion.
# ----------
# Retriving data for Index 1: Ilulissat.
# ----------
# Retriving data for Index 2: Guerrero Negro.
# ----------
# Retriving data for Index 3: Rawannawi.
# Data missing. Skipping
# ----------
# Retriving data for Index 4: Punta Arenas.
# ----------
# Retriving data for Index 5: Cherskiy.
# ----------
# Retriving data for Index 6: Atuona.
# ----------
# Retriving data for Index 7: Lebu.
# ----------
# Retriving data for Index 8: Upernavik.
# ----------
# Retriving data for Index 9: Mataura.
# ----------
# Retriving data for Index 10: Bathsheba.
# ----------
# Retriving data for Index 11: Portland.
# ----------
# Retriving data for Index 12: Margate.
# ----------
# Retriving data for Index 13: Busselton.
# ----------
# Retriving data for Index 14: Hasaki.
# ----------
# Retriving data for Index 15: Alta Floresta.
# ----------
# Retriving data for Index 16: Airai.
# ----------
# Retriving data for Index 17: Fortuna.
# ----------
# Retriving data for Index 18: Port Alfred.
# ----------
# Retriving data for Index 19: Tuktoyaktuk.
# ----------
# Retriving data for Index 20: Albany.
# ----------
# Retriving data for Index 21: Kapaa.
# ----------
# Retriving data for Index 22: Vanimo.
# ----------
# Retriving data for Index 23: Srednekolymsk.
# ----------
# Retriving data for Index 24: Chuy.
# ----------
# Retriving data for Index 25: Chernyshevskiy.
# ----------
# Retriving data for Index 26: Namibe.
# ----------
# Retriving data for Index 27: Lichtenburg.
# ----------
# Retriving data for Index 28: Chlorakas.
# Data missing. Skipping
# ----------
# Retriving data for Index 29: Kavieng.
# ----------
# Retriving data for Index 30: Gravdal.
# ----------
# Retriving data for Index 31: Ushuaia.
# ----------
# Retriving data for Index 32: Lata.
# ----------
# Retriving data for Index 33: Cape Town.
# ----------
# Retriving data for Index 34: Castro.
# ----------
# Retriving data for Index 35: Jamestown.
# ----------
# Retriving data for Index 36: Rikitea.
# ----------
# Retriving data for Index 37: Poum.
# ----------
# Retriving data for Index 38: Port Hedland.
# ----------
# Retriving data for Index 39: Amderma.
# Data missing. Skipping
# ----------
# Retriving data for Index 40: Ostrovnoy.
# ----------
# Retriving data for Index 41: Ardistan.
# Data missing. Skipping
# ----------
# Retriving data for Index 42: Bredasdorp.
# ----------
# Retriving data for Index 43: Saint-Philippe.
# ----------
# Retriving data for Index 44: Saleaula.
# Data missing. Skipping
# ----------
# Retriving data for Index 45: Kapoeta.
# Data missing. Skipping
# ----------
# Retriving data for Index 46: Revelstoke.
# ----------
# Retriving data for Index 47: Nikolskoye.
# ----------
# Retriving data for Index 48: Rafaela.
# ----------
# Retriving data for Index 49: Souillac.
# ----------
# Retriving data for Index 50: Hobart.
# ----------
# Retriving data for Index 51: Alofi.
# ----------
# Retriving data for Index 52: Barrow.
# ----------
# Retriving data for Index 53: Holbeach.
# ----------
# Retriving data for Index 54: Virginia Beach.
# ----------
# Retriving data for Index 55: Bluff.
# ----------
# Retriving data for Index 56: Mount Isa.
# ----------
# Retriving data for Index 57: Olafsvik.
# Data missing. Skipping
# ----------
# Retriving data for Index 58: Benguela.
# ----------
# Retriving data for Index 59: Estrela.
# ----------
# Retriving data for Index 60: Vaini.
# ----------
# Retriving data for Index 61: San Policarpo.
# ----------
# Retriving data for Index 62: Lisakovsk.
# ----------
# Retriving data for Index 63: Saint-Pacome.
# Data missing. Skipping
# ----------
# Retriving data for Index 64: Havre-Saint-Pierre.
# ----------
# Retriving data for Index 65: Hermanus.
# ----------
# Retriving data for Index 66: Port Blair.
# ----------
# Retriving data for Index 67: Hilo.
# ----------
# Retriving data for Index 68: Mar Del Plata.
# ----------
# Retriving data for Index 69: Erzin.
# ----------
# Retriving data for Index 70: Butaritari.
# ----------
# Retriving data for Index 71: Ponta Do Sol.
# ----------
# Retriving data for Index 72: Tomatlan.
# ----------
# Retriving data for Index 73: Corinth.
# ----------
# Retriving data for Index 74: Libreville.
# ----------
# Retriving data for Index 75: Mae Sai.
# ----------
# Retriving data for Index 76: Yellandu.
# ----------
# Retriving data for Index 77: Eidfjord.
# ----------
# Retriving data for Index 78: Pacific Grove.
# ----------
# Retriving data for Index 79: Silver City.
# ----------
# Retriving data for Index 80: Coihaique.
# ----------
# Retriving data for Index 81: Morant Bay.
# ----------
# Retriving data for Index 82: Lakselv.
# ----------
# Retriving data for Index 83: Puerto Ayora.
# ----------
# Retriving data for Index 84: Severo-Kurilsk.
# ----------
# Retriving data for Index 85: Matay.
# ----------
# Retriving data for Index 86: Vila Franca Do Campo.
# ----------
# Retriving data for Index 87: Illoqqortoormiut.
# Data missing. Skipping
# ----------
# Retriving data for Index 88: Deputatskiy.
# ----------
# Retriving data for Index 89: Jurm.
# ----------
# Retriving data for Index 90: Baboua.
# Data missing. Skipping
# ----------
# Retriving data for Index 91: Bilibino.
# ----------
# Retriving data for Index 92: Fuente De Oro.
# ----------
# Retriving data for Index 93: Marsh Harbour.
# ----------
# Retriving data for Index 94: Selcuk.
# ----------
# Retriving data for Index 95: Gua Musang.
# ----------
# Retriving data for Index 96: Bako.
# ----------
# Retriving data for Index 97: Thompson.
# ----------
# Retriving data for Index 98: Narsaq.
# ----------
# Retriving data for Index 99: Rio Gallegos.
# ----------
# Retriving data for Index 100: Colesberg.
# ----------
# Retriving data for Index 101: Mashivka.
# ----------
# Retriving data for Index 102: Kamenskoye.
# Data missing. Skipping
# ----------
# Retriving data for Index 103: Balabac.
# ----------
# Retriving data for Index 104: Hobyo.
# ----------
# Retriving data for Index 105: Chara.
# ----------
# Retriving data for Index 106: Oktyabrskiy.
# ----------
# Retriving data for Index 107: Longyearbyen.
# ----------
# Retriving data for Index 108: New Norfolk.
# ----------
# Retriving data for Index 109: Fairbanks.
# ----------
# Retriving data for Index 110: Sorland.
# ----------
# Retriving data for Index 111: Qaanaaq.
# ----------
# Retriving data for Index 112: Skagastrond.
# Data missing. Skipping
# ----------
# Retriving data for Index 113: Rawson.
# ----------
# Retriving data for Index 114: Katherine.
# ----------
# Retriving data for Index 115: Shimorskoye.
# ----------
# Retriving data for Index 116: Lompoc.
# ----------
# Retriving data for Index 117: Umzimvubu.
# Data missing. Skipping
# ----------
# Retriving data for Index 118: Vila Velha.
# ----------
# Retriving data for Index 119: Arraial Do Cabo.
# ----------
# Retriving data for Index 120: Aykhal.
# ----------
# Retriving data for Index 121: Tura.
# ----------
# Retriving data for Index 122: Nador.
# ----------
# Retriving data for Index 123: Mahebourg.
# ----------
# Retriving data for Index 124: Obo.
# ----------
# Retriving data for Index 125: Nabire.
# ----------
# Retriving data for Index 126: Kasane.
# ----------
# Retriving data for Index 127: Sitka.
# ----------
# Retriving data for Index 128: Tiksi.
# ----------
# Retriving data for Index 129: Price.
# ----------
# Retriving data for Index 130: Erenhot.
# ----------
# Retriving data for Index 131: Coria.
# ----------
# Retriving data for Index 132: Taoudenni.
# ----------
# Retriving data for Index 133: Kruisfontein.
# ----------
# Retriving data for Index 134: Cidreira.
# ----------
# Retriving data for Index 135: Birin.
# ----------
# Retriving data for Index 136: Vardo.
# ----------
# Retriving data for Index 137: Yurino.
# ----------
# Retriving data for Index 138: Puerto Escondido.
# ----------
# Retriving data for Index 139: Barentsburg.
# Data missing. Skipping
# ----------
# Retriving data for Index 140: Carnarvon.
# ----------
# Retriving data for Index 141: Tuatapere.
# ----------
# Retriving data for Index 142: Laguna.
# ----------
# Retriving data for Index 143: Bambous Virieux.
# ----------
# Retriving data for Index 144: Port Said.
# ----------
# Retriving data for Index 145: Avarua.
# ----------
# Retriving data for Index 146: Tilichiki.
# ----------
# Retriving data for Index 147: Saint George.
# ----------
# Retriving data for Index 148: Sakakah.
# Data missing. Skipping
# ----------
# Retriving data for Index 149: Poya.
# ----------
# Retriving data for Index 150: San Bartolo Del Llano.
# ----------
# Retriving data for Index 151: Sitio Novo Do Tocantins.
# Data missing. Skipping
# ----------
# Retriving data for Index 152: Yellowknife.
# ----------
# Retriving data for Index 153: Santa Maria.
# ----------
# Retriving data for Index 154: Provideniya.
# ----------
# Retriving data for Index 155: Georgetown.
# ----------
# Retriving data for Index 156: Saint Anthony.
# ----------
# Retriving data for Index 157: Karkaralinsk.
# Data missing. Skipping
# ----------
# Retriving data for Index 158: Gat.
# ----------
# Retriving data for Index 159: Lavrentiya.
# ----------
# Retriving data for Index 160: Kem.
# ----------
# Retriving data for Index 161: Dikson.
# ----------
# Retriving data for Index 162: Ketchikan.
# ----------
# Retriving data for Index 163: Kingaroy.
# ----------
# Retriving data for Index 164: Trat.
# ----------
# Retriving data for Index 165: Ovre Ardal.
# ----------
# Retriving data for Index 166: Anloga.
# ----------
# Retriving data for Index 167: Beisfjord.
# ----------
# Retriving data for Index 168: Beni Mazar.
# ----------
# Retriving data for Index 169: Tsogni.
# ----------
# Retriving data for Index 170: Hailey.
# ----------
# Retriving data for Index 171: Beatrice.
# ----------
# Retriving data for Index 172: Bulgan.
# ----------
# Retriving data for Index 173: Nhulunbuy.
# ----------
# Retriving data for Index 174: Paamiut.
# ----------
# Retriving data for Index 175: Traverse City.
# ----------
# Retriving data for Index 176: Gannan.
# ----------
# Retriving data for Index 177: Taolanaro.
# Data missing. Skipping
# ----------
# Retriving data for Index 178: Cabedelo.
# ----------
# Retriving data for Index 179: Kodiak.
# ----------
# Retriving data for Index 180: Mahadday Weyne.
# Data missing. Skipping
# ----------
# Retriving data for Index 181: Sola.
# ----------
# Retriving data for Index 182: Bukama.
# ----------
# Retriving data for Index 183: Tasiilaq.
# ----------
# Retriving data for Index 184: Curup.
# ----------
# Retriving data for Index 185: Koster.
# ----------
# Retriving data for Index 186: Tumannyy.
# Data missing. Skipping
# ----------
# Retriving data for Index 187: Esperance.
# ----------
# Retriving data for Index 188: Dhidhdhoo.
# ----------
# Retriving data for Index 189: Vila Do Maio.
# ----------
# Retriving data for Index 190: Manzhouli.
# ----------
# Retriving data for Index 191: Asfi.
# Data missing. Skipping
# ----------
# Retriving data for Index 192: Bengkulu.
# Data missing. Skipping
# ----------
# Retriving data for Index 193: Komsomolskiy.
# ----------
# Retriving data for Index 194: Nizhneyansk.
# Data missing. Skipping
# ----------
# Retriving data for Index 195: Atambua.
# ----------
# Retriving data for Index 196: Yenagoa.
# ----------
# Retriving data for Index 197: Codrington.
# ----------
# Retriving data for Index 198: Nazira.
# ----------
# Retriving data for Index 199: Atasu.
# ----------
# Retriving data for Index 200: Bachi-Yurt.
# ----------
# Retriving data for Index 201: Flinders.
# ----------
# Retriving data for Index 202: Zaozerne.
# ----------
# Retriving data for Index 203: Hovd.
# ----------
# Retriving data for Index 204: Khatanga.
# ----------
# Retriving data for Index 205: Vaitupu.
# Data missing. Skipping
# ----------
# Retriving data for Index 206: Coffs Harbour.
# ----------
# Retriving data for Index 207: Nueva Helvecia.
# ----------
# Retriving data for Index 208: Roald.
# ----------
# Retriving data for Index 209: Ketou.
# ----------
# Retriving data for Index 210: Clyde River.
# ----------
# Retriving data for Index 211: Walvis Bay.
# ----------
# Retriving data for Index 212: Kingisepp.
# ----------
# Retriving data for Index 213: Todos Santos.
# ----------
# Retriving data for Index 214: Samusu.
# Data missing. Skipping
# ----------
# Retriving data for Index 215: Okato.
# ----------
# Retriving data for Index 216: Mys Shmidta.
# Data missing. Skipping
# ----------
# Retriving data for Index 217: Aban.
# Data missing. Skipping
# ----------
# Retriving data for Index 218: Altay.
# ----------
# Retriving data for Index 219: San Quintin.
# ----------
# Retriving data for Index 220: Thinadhoo.
# ----------
# Retriving data for Index 221: San Juan.
# ----------
# Retriving data for Index 222: Kuminskiy.
# ----------
# Retriving data for Index 223: East London.
# ----------
# Retriving data for Index 224: Harij.
# ----------
# Retriving data for Index 225: Norman Wells.
# ----------
# Retriving data for Index 226: Juazeirinho.
# ----------
# Retriving data for Index 227: Port Elizabeth.
# ----------
# Retriving data for Index 228: Chokurdakh.
# ----------
# Retriving data for Index 229: Adrar.
# ----------
# Retriving data for Index 230: Valparaiso.
# ----------
# Retriving data for Index 231: Nguiu.
# Data missing. Skipping
# ----------
# Retriving data for Index 232: Rosarito.
# ----------
# Retriving data for Index 233: San Patricio.
# ----------
# Retriving data for Index 234: Matagami.
# ----------
# Retriving data for Index 235: Yulara.
# ----------
# Retriving data for Index 236: Seymchan.
# ----------
# Retriving data for Index 237: Saint-Pierre.
# ----------
# Retriving data for Index 238: Wahiawa.
# ----------
# Retriving data for Index 239: Salinas.
# ----------
# Retriving data for Index 240: Iquitos.
# ----------
# Retriving data for Index 241: Phalodi.
# ----------
# Retriving data for Index 242: Beloha.
# ----------
# Retriving data for Index 243: Marcona.
# Data missing. Skipping
# ----------
# Retriving data for Index 244: Geraldton.
# ----------
# Retriving data for Index 245: Atagay.
# ----------
# Retriving data for Index 246: Takoradi.
# ----------
# Retriving data for Index 247: Saint-Augustin.
# ----------
# Retriving data for Index 248: Lorengau.
# ----------
# Retriving data for Index 249: Port Lincoln.
# ----------
# Retriving data for Index 250: Susah.
# Data missing. Skipping
# ----------
# Retriving data for Index 251: Awbari.
# ----------
# Retriving data for Index 252: Hambantota.
# ----------
# Retriving data for Index 253: Ochakiv.
# ----------
# Retriving data for Index 254: Sentyabrskiy.
# Data missing. Skipping
# ----------
# Retriving data for Index 255: Mookane.
# ----------
# Retriving data for Index 256: Jaisalmer.
# ----------
# Retriving data for Index 257: Ventspils.
# ----------
# Retriving data for Index 258: Viedma.
# ----------
# Retriving data for Index 259: Belaya Gora.
# ----------
# Retriving data for Index 260: Richards Bay.
# ----------
# Retriving data for Index 261: Ndele.
# Data missing. Skipping
# ----------
# Retriving data for Index 262: Khorixas.
# ----------
# Retriving data for Index 263: Salalah.
# ----------
# Retriving data for Index 264: Yatou.
# ----------
# Retriving data for Index 265: Omis.
# ----------
# Retriving data for Index 266: Ahipara.
# ----------
# Retriving data for Index 267: Saskylakh.
# ----------
# Retriving data for Index 268: Bethel.
# ----------
# Retriving data for Index 269: Katsuura.
# ----------
# Retriving data for Index 270: Presidencia Roque Saenz Pena.
# ----------
# Retriving data for Index 271: Altamirano.
# ----------
# Retriving data for Index 272: Tulun.
# ----------
# Retriving data for Index 273: Camden.
# ----------
# Retriving data for Index 274: Ludvika.
# ----------
# Retriving data for Index 275: Cozumel.
# Data missing. Skipping
# ----------
# Retriving data for Index 276: Zhigansk.
# ----------
# Retriving data for Index 277: Susangerd.
# ----------
# Retriving data for Index 278: Pevek.
# ----------
# Retriving data for Index 279: Tabiauea.
# Data missing. Skipping
# ----------
# Retriving data for Index 280: Straumen.
# ----------
# Retriving data for Index 281: Cassilandia.
# ----------
# Retriving data for Index 282: Miramar.
# ----------
# Retriving data for Index 283: Guilin.
# ----------
# Retriving data for Index 284: Rzeszow.
# ----------
# Retriving data for Index 285: Camacha.
# ----------
# Retriving data for Index 286: Pisco.
# ----------
# Retriving data for Index 287: Tsihombe.
# Data missing. Skipping
# ----------
# Retriving data for Index 288: Scarborough.
# ----------
# Retriving data for Index 289: Hithadhoo.
# ----------
# Retriving data for Index 290: Westport.
# ----------
# Retriving data for Index 291: Inongo.
# ----------
# Retriving data for Index 292: Sayyan.
# ----------
# Retriving data for Index 293: Bonnyville.
# ----------
# Retriving data for Index 294: Sao Filipe.
# ----------
# Retriving data for Index 295: Ngaoundere.
# ----------
# Retriving data for Index 296: Juegang.
# ----------
# Retriving data for Index 297: Necochea.
# ----------
# Retriving data for Index 298: Kimberley.
# ----------
# Retriving data for Index 299: Iqaluit.
# ----------
# Retriving data for Index 300: Ca Mau.
# ----------
# Retriving data for Index 301: Tonj.
# Data missing. Skipping
# ----------
# Retriving data for Index 302: Oksfjord.
# ----------
# Retriving data for Index 303: Leningradskiy.
# ----------
# Retriving data for Index 304: Tabuk.
# ----------
# Retriving data for Index 305: Yumen.
# ----------
# Retriving data for Index 306: Dingle.
# ----------
# Retriving data for Index 307: Port Arthur.
# ----------
# Retriving data for Index 308: Chicama.
# ----------
# Retriving data for Index 309: Yarmouth.
# ----------
# Retriving data for Index 310: Xining.
# ----------
# Retriving data for Index 311: Anadyr.
# ----------
# Retriving data for Index 312: Opuwo.
# ----------
# Retriving data for Index 313: Rocha.
# ----------
# Retriving data for Index 314: Russell.
# ----------
# Retriving data for Index 315: Praya.
# ----------
# Retriving data for Index 316: Grindavik.
# ----------
# Retriving data for Index 317: Houma.
# ----------
# Retriving data for Index 318: Ribeira Grande.
# ----------
# Retriving data for Index 319: Inuvik.
# ----------
# Retriving data for Index 320: Tommot.
# ----------
# Retriving data for Index 321: Mogoytuy.
# ----------
# Retriving data for Index 322: Manzil Tamim.
# Data missing. Skipping
# ----------
# Retriving data for Index 323: Mahajanga.
# ----------
# Retriving data for Index 324: Dzialdowo.
# ----------
# Retriving data for Index 325: Kwinana.
# ----------
# Retriving data for Index 326: Montreal.
# ----------
# Retriving data for Index 327: Kamenka.
# ----------
# Retriving data for Index 328: Buala.
# ----------
# Retriving data for Index 329: North Bend.
# ----------
# Retriving data for Index 330: Bowmore.
# ----------
# Retriving data for Index 331: Petropavlovsk-Kamchatskiy.
# ----------
# Retriving data for Index 332: Asilah.
# Data missing. Skipping
# ----------
# Retriving data for Index 333: Saint-Paul-Les-Dax.
# ----------
# Retriving data for Index 334: Cabo San Lucas.
# ----------
# Retriving data for Index 335: Carikar.
# Data missing. Skipping
# ----------
# Retriving data for Index 336: Luderitz.
# ----------
# Retriving data for Index 337: Cururupu.
# ----------
# Retriving data for Index 338: Ushtobe.
# ----------
# Retriving data for Index 339: Arlit.
# ----------
# Retriving data for Index 340: Pasinler.
# ----------
# Retriving data for Index 341: Ahumada.
# Data missing. Skipping
# ----------
# Retriving data for Index 342: Burla.
# ----------
# Retriving data for Index 343: Tshikapa.
# ----------
# Retriving data for Index 344: Port-Gentil.
# ----------
# Retriving data for Index 345: Sorong.
# ----------
# Retriving data for Index 346: Toma.
# ----------
# Retriving data for Index 347: Karratha.
# ----------
# Retriving data for Index 348: Arona.
# ----------
# Retriving data for Index 349: Seoul.
# ----------
# Retriving data for Index 350: Aljezur.
# ----------
# Retriving data for Index 351: Victoria.
# ----------
# Retriving data for Index 352: Darnah.
# ----------
# Retriving data for Index 353: Mitu.
# ----------
# Retriving data for Index 354: Tevriz.
# ----------
# Retriving data for Index 355: Orzu.
# ----------
# Retriving data for Index 356: Garowe.
# ----------
# Retriving data for Index 357: Serebryansk.
# ----------
# Retriving data for Index 358: Dalbandin.
# ----------
# Retriving data for Index 359: Nangomba.
# ----------
# Retriving data for Index 360: Karlskrona.
# ----------
# Retriving data for Index 361: Umm Lajj.
# ----------
# Retriving data for Index 362: Dukat.
# ----------
# Retriving data for Index 363: Taburi.
# Data missing. Skipping
# ----------
# Retriving data for Index 364: Belushya Guba.
# Data missing. Skipping
# ----------
# Retriving data for Index 365: Grass Valley.
# ----------
# Retriving data for Index 366: Husavik.
# ----------
# Retriving data for Index 367: Jardim.
# ----------
# Retriving data for Index 368: Balad.
# ----------
# Retriving data for Index 369: Moyale.
# ----------
# Retriving data for Index 370: Cheuskiny.
# Data missing. Skipping
# ----------
# Retriving data for Index 371: Serenje.
# ----------
# Retriving data for Index 372: Ruatoria.
# Data missing. Skipping
# ----------
# Retriving data for Index 373: Mareeba.
# ----------
# Retriving data for Index 374: Velke Karlovice.
# ----------
# Retriving data for Index 375: Jeremoabo.
# ----------
# Retriving data for Index 376: Darhan.
# ----------
# Retriving data for Index 377: Ures.
# ----------
# Retriving data for Index 378: Kavaratti.
# ----------
# Retriving data for Index 379: Oranjestad.
# ----------
# Retriving data for Index 380: Ojinaga.
# ----------
# Retriving data for Index 381: Jabinyanah.
# ----------
# Retriving data for Index 382: Bandar-E Lengeh.
# ----------
# Retriving data for Index 383: Nantucket.
# ----------
# Retriving data for Index 384: Kogon.
# ----------
# Retriving data for Index 385: Biskamzha.
# ----------
# Retriving data for Index 386: Tautira.
# ----------
# Retriving data for Index 387: Fort Myers Beach.
# ----------
# Retriving data for Index 388: San Andres.
# ----------
# Retriving data for Index 389: Korla.
# Data missing. Skipping
# ----------
# Retriving data for Index 390: Maua.
# ----------
# Retriving data for Index 391: Angoche.
# ----------
# Retriving data for Index 392: Ondorhaan.
# Data missing. Skipping
# ----------
# Retriving data for Index 393: Palabuhanratu.
# Data missing. Skipping
# ----------
# Retriving data for Index 394: Nortelandia.
# ----------
# Retriving data for Index 395: Riaba.
# Data missing. Skipping
# ----------
# Retriving data for Index 396: Hwange.
# ----------
# Retriving data for Index 397: Correntina.
# ----------
# Retriving data for Index 398: Antofagasta.
# ----------
# Retriving data for Index 399: Aleksandrov Gay.
# ----------
# Retriving data for Index 400: Santiago Del Estero.
# ----------
# Retriving data for Index 401: San Marcos.
# ----------
# Retriving data for Index 402: Alakurtti.
# ----------
# Retriving data for Index 403: Lyubashivka.
# ----------
# Retriving data for Index 404: Cayenne.
# ----------
# Retriving data for Index 405: Sena Madureira.
# ----------
# Retriving data for Index 406: Sabinopolis.
# ----------
# Retriving data for Index 407: Kashi.
# Data missing. Skipping
# ----------
# Retriving data for Index 408: Meulaboh.
# ----------
# Retriving data for Index 409: Kondinskoye.
# ----------
# Retriving data for Index 410: Maroslele.
# ----------
# Retriving data for Index 411: Sao Joao Da Barra.
# ----------
# Retriving data for Index 412: Traunstein.
# ----------
# Retriving data for Index 413: Kapuskasing.
# ----------
# Retriving data for Index 414: Quesnel.
# ----------
# Retriving data for Index 415: Amor.
# ----------
# Retriving data for Index 416: Klaksvik.
# ----------
# Retriving data for Index 417: Xuddur.
# ----------
# Retriving data for Index 418: Tambovka.
# ----------
# Retriving data for Index 419: Sambava.
# ----------
# Retriving data for Index 420: San Cristobal.
# ----------
# Retriving data for Index 421: Rungata.
# Data missing. Skipping
# ----------
# Retriving data for Index 422: Whitehorse.
# ----------
# Retriving data for Index 423: Kropotkin.
# ----------
# Retriving data for Index 424: Sovetskaya Gavan.
# ----------
# Retriving data for Index 425: Hearst.
# ----------
# Retriving data for Index 426: Shiyan.
# ----------
# Retriving data for Index 427: Wilmington.
# ----------
# Retriving data for Index 428: Labuhan.
# ----------
# Retriving data for Index 429: Kozhva.
# ----------
# Retriving data for Index 430: Lolua.
# Data missing. Skipping
# ----------
# Retriving data for Index 431: Talcahuano.
# ----------
# Retriving data for Index 432: Malakal.
# Data missing. Skipping
# ----------
# Retriving data for Index 433: Sorvag.
# Data missing. Skipping
# ----------
# Retriving data for Index 434: Attawapiskat.
# Data missing. Skipping
# ----------
# Retriving data for Index 435: Mozarlandia.
# ----------
# Retriving data for Index 436: Lagoa.
# ----------
# Retriving data for Index 437: Marystown.
# ----------
# Retriving data for Index 438: Falam.
# ----------
# Retriving data for Index 439: Diu.
# ----------
# Retriving data for Index 440: Lexington.
# ----------
# Retriving data for Index 441: Shimoda.
# ----------
# Retriving data for Index 442: Khovu-Aksy.
# ----------
# Retriving data for Index 443: Fereydun Kenar.
# ----------
# Retriving data for Index 444: Crateus.
# ----------
# Retriving data for Index 445: Maldonado.
# ----------
# Retriving data for Index 446: Ken Caryl.
# ----------
# Retriving data for Index 447: Washington.
# ----------
# Retriving data for Index 448: Bograd.
# ----------
# Retriving data for Index 449: Saint-Denis.
# ----------
# Retriving data for Index 450: Griffith.
# ----------
# Retriving data for Index 451: Pingliang.
# ----------
# Retriving data for Index 452: Maniitsoq.
# ----------
# Retriving data for Index 453: Harper.
# ----------
# Retriving data for Index 454: Soe.
# ----------
# Retriving data for Index 455: Manta.
# ----------
# Retriving data for Index 456: Camopi.
# ----------
# Retriving data for Index 457: Ostersund.
# ----------
# Retriving data for Index 458: Lasa.
# ----------
# Retriving data for Index 459: Rondonopolis.
# ----------
# Retriving data for Index 460: Hampton.
# ----------
# Retriving data for Index 461: Oistins.
# ----------
# Retriving data for Index 462: Nemuro.
# ----------
# Retriving data for Index 463: Burns Lake.
# ----------
# Retriving data for Index 464: Zomin.
# ----------
# Retriving data for Index 465: Ximei.
# ----------
# Retriving data for Index 466: Mugur-Aksy.
# ----------
# Retriving data for Index 467: Kaitangata.
# ----------
# Retriving data for Index 468: Amelia.
# ----------
# Retriving data for Index 469: Haines Junction.
# ----------
# Retriving data for Index 470: Desbiens.
# ----------
# Retriving data for Index 471: Padang.
# ----------
# Retriving data for Index 472: Katangli.
# ----------
# Retriving data for Index 473: Guiratinga.
# ----------
# Retriving data for Index 474: Tres Palos.
# ----------
# Retriving data for Index 475: Polillo.
# ----------
# Retriving data for Index 476: Barawe.
# Data missing. Skipping
# ----------
# Retriving data for Index 477: Havoysund.
# ----------
# Retriving data for Index 478: Terrace Bay.
# ----------
# Retriving data for Index 479: Yeppoon.
# ----------
# Retriving data for Index 480: Ambon.
# ----------
# Retriving data for Index 481: Muros.
# ----------
# Retriving data for Index 482: Grand Centre.
# Data missing. Skipping
# ----------
# Retriving data for Index 483: Hlobyne.
# ----------
# Retriving data for Index 484: Los Llanos De Aridane.
# ----------
# Retriving data for Index 485: Reconquista.
# ----------
# Retriving data for Index 486: Hami.
# ----------
# Retriving data for Index 487: Palmerston North.
# ----------
# Retriving data for Index 488: Jieshi.
# ----------
# Retriving data for Index 489: Sangmelima.
# ----------
# Retriving data for Index 490: Kumba.
# ----------
# Retriving data for Index 491: Port Hardy.
# ----------
# Retriving data for Index 492: Zachagansk.
# Data missing. Skipping
# ----------
# Retriving data for Index 493: Campos Belos.
# ----------
# Retriving data for Index 494: Mackay.
# ----------
# Retriving data for Index 495: Kasongo-Lunda.
# ----------
# Retriving data for Index 496: Puerto Maldonado.
# ----------
# Retriving data for Index 497: Axim.
# ----------
# Retriving data for Index 498: Mao.
# ----------
# Retriving data for Index 499: Intipuca.
# ----------
# Retriving data for Index 500: Tessalit.
# ----------
# Retriving data for Index 501: Golden.
# ----------
# Retriving data for Index 502: Sibolga.
# ----------
# Retriving data for Index 503: Ust-Nera.
# ----------
# Retriving data for Index 504: Leh.
# ----------
# Retriving data for Index 505: Half Moon Bay.
# ----------
# Retriving data for Index 506: Mawlaik.
# ----------
# Retriving data for Index 507: Warqla.
# Data missing. Skipping
# ----------
# Retriving data for Index 508: Wasilla.
# ----------
# Retriving data for Index 509: Rajapolah.
# ----------
# Retriving data for Index 510: Karamea.
# Data missing. Skipping
# ----------
# Retriving data for Index 511: Minab.
# ----------
# Retriving data for Index 512: Tupik.
# ----------
# Retriving data for Index 513: Khuzhir.
# ----------
# Retriving data for Index 514: Westpunt.
# Data missing. Skipping
# ----------
# Retriving data for Index 515: Quatre Cocos.
# ----------
# Retriving data for Index 516: Dese.
# ----------
# Retriving data for Index 517: Okha.
# ----------
# Retriving data for Index 518: Byron Bay.
# ----------
# Retriving data for Index 519: Karaton.
# ----------
# Retriving data for Index 520: Warwick.
# ----------
# Retriving data for Index 521: Bababe.
# Data missing. Skipping
# ----------
# Retriving data for Index 522: Macklin.
# ----------
# Retriving data for Index 523: Torbay.
# ----------
# Retriving data for Index 524: Samarai.
# ----------
# Retriving data for Index 525: Svetlyy.
# Data missing. Skipping
# ----------
# Retriving data for Index 526: San Carlos De Bariloche.
# ----------
# Retriving data for Index 527: Palana.
# ----------
# Retriving data for Index 528: Pangoa.
# ----------
# Retriving data for Index 529: Siilinjarvi.
# ----------
# Retriving data for Index 530: Marsaxlokk.
# ----------
# Retriving data for Index 531: Bairiki.
# Data missing. Skipping
# ----------
# Retriving data for Index 532: Karasburg.
# ----------
# Retriving data for Index 533: Sisimiut.
# ----------
# Retriving data for Index 534: Lebork.
# ----------
# Retriving data for Index 535: Bacungan.
# ----------
# Retriving data for Index 536: Kirakira.
# ----------
# Retriving data for Index 537: Sahuaripa.
# ----------
# Retriving data for Index 538: Surt.
# ----------
# Retriving data for Index 539: San Ramon.
# ----------
# Retriving data for Index 540: Stromness.
# ----------
# Retriving data for Index 541: Qarqin.
# ----------
# Retriving data for Index 542: Mount Gambier.
# ----------
# Retriving data for Index 543: Bonavista.
# ----------
# Retriving data for Index 544: Zhanaozen.
# ----------
# Retriving data for Index 545: Karasjok.
# ----------
# Retriving data for Index 546: Nchelenge.
# ----------
# Retriving data for Index 547: Jacareacanga.
# ----------
# Retriving data for Index 548: Turukhansk.
# ----------
# Retriving data for Index 549: Kuche.
# Data missing. Skipping
# ----------
# Retriving data for Index 550: Agadez.
# ----------
# Retriving data for Index 551: Beringovskiy.
# ----------
# Retriving data for Index 552: Port Keats.
# ----------
# Retriving data for Index 553: Trinidad.
# ----------
# Retriving data for Index 554: Lumphat.
# ----------
# Retriving data for Index 555: Aktau.
# ----------
# Retriving data for Index 556: Saint-Georges.
# ----------
# Retriving data for Index 557: Kichmengskiy Gorodok.
# ----------
# Retriving data for Index 558: Grand Gaube.
# ----------
# Retriving data for Index 559: Sol-Iletsk.
# ----------
# Retriving data for Index 560: Fort Nelson.
# ----------
# Retriving data for Index 561: Kimparana.
# ----------
# Retriving data for Index 562: Isangel.
# ----------
# Retriving data for Index 563: Yerbogachen.
# ----------
# Retriving data for Index 564: Barahona.
# ----------
# Retriving data for Index 565: Kangaatsiaq.
# ----------
# Retriving data for Index 566: Haapiti.
# ----------
# Retriving data for Index 567: Asosa.
# ----------
# Retriving data for Index 568: Yugo-Kamskiy.
# ----------
# Retriving data for Index 569: Tygda.
# ----------
# Retriving data for Index 570: Mayor Pablo Lagerenza.
# ----------
# Retriving data for Index 571: Waipawa.
# ----------
# Retriving data for Index 572: Sistranda.
# ----------
# Retriving data for Index 573: Avera.
# ----------
# Retriving data for Index 574: Chapada Dos Guimaraes.
# ----------
# Retriving data for Index 575: Tuggurt.
# Data missing. Skipping
# ----------
# Retriving data for Index 576: Burgeo.
# ----------
# Retriving data for Index 577: Lieksa.
# ----------
# Retriving data for Index 578: Grand River South East.
# Data missing. Skipping
# ----------
# Retriving data for Index 579: Dien Bien.
# Data missing. Skipping
# ----------
# Retriving data for Index 580: Faanui.
# ----------
# Retriving data for Index 581: Gambo.
# ----------
# Retriving data for Index 582: Karsava.
# ----------
# Retriving data for Index 583: Mitsamiouli.
# ----------
# Retriving data for Index 584: Broken Hill.
# ----------
# Retriving data for Index 585: Menuma.
# ----------
# Retriving data for Index 586: Tezu.
# ----------
# Retriving data for Index 587: Miles City.
# ----------
# Retriving data for Index 588: Nanortalik.
# ----------
# Retriving data for Index 589: Le Vauclin.
# ----------
# Retriving data for Index 590: Nouadhibou.
# ----------
# Retriving data for Index 591: Kutum.
# ----------
# Retriving data for Index 592: Skalistyy.
# Data missing. Skipping
# ----------
# Retriving data for Index 593: Koumac.
# ----------
# Retriving data for Index 594: Agva.
# Data missing. Skipping
# ----------
# Retriving data for Index 595: Kalmunai.
# ----------
# Retriving data for Index 596: Asau.
# Data missing. Skipping
# ----------
# Retriving data for Index 597: Doha.
# ----------
# Retriving data for Index 598: Charters Towers.
# ----------
# Retriving data for Index 599: Dolinsk.
# ----------
# Retriving data for Index 600: Riyadh.
# ----------
# Retriving data for Index 601: Mandiana.
# ----------
# Retriving data for Index 602: Tungor.
# ----------
# Retriving data for Index 603: Perevolotskiy.
# ----------
# Retriving data for Index 604: Rupert.
# ----------
# Retriving data for Index 605: Dongli.
# ----------
# Retriving data for Index 606: Leshukonskoye.
# ----------
# Retriving data for Index 607: Royan.
# ----------
# Retriving data for Index 608: Muroto.
# ----------
# Retriving data for Index 609: Grand-Santi.
# ----------
# Retriving data for Index 610: Mangrol.
# ----------
# Retriving data for Index 611: Chunskiy.
# ----------
# Retriving data for Index 612: Gamba.
# ----------
# Retriving data for Index 613: Stettler.
# ----------
# Retriving data for Index 614: Kilindoni.
# ----------
# Retriving data for Index 615: Moose Factory.
# ----------
# Retriving data for Index 616: Vao.
# ----------
# Retriving data for Index 617: Levelland.
# ----------
# Retriving data for Index 618: Vernon.
# ----------
# Retriving data for Index 619: Shreveport.
# ----------
# Retriving data for Index 620: Lhokseumawe.
# ----------
# Retriving data for Index 621: Vostok.
# ----------
# Retriving data for Index 622: Kitimat.
# ----------
# Retriving data for Index 623: Rio Rancho.
# ----------
# Retriving data for Index 624: Saldanha.
# ----------
# Retriving data for Index 625: Hervey Bay.
# ----------
# Retriving data for Index 626: Codo.
# ----------
# Retriving data for Index 627: Arman.
# ----------
# Retriving data for Index 628: Oranjemund.
# ----------
# Retriving data for Index 629: Port Pirie.
# ----------
# Retriving data for Index 630: Tarudant.
# Data missing. Skipping
# ----------
# Retriving data for Index 631: Bambanglipuro.
# ----------
# Retriving data for Index 632: Naklo Nad Notecia.
# ----------
# Retriving data for Index 633: Broome.
# ----------
# Retriving data for Index 634: Mayo.
# ----------
# Retriving data for Index 635: Tateyama.
# ----------
# Retriving data for Index 636: Aklavik.
# ----------
# Retriving data for Index 637: Bafoulabe.
# ----------
# Retriving data for Index 638: Te Anau.
# ----------
# Retriving data for Index 639: Canton.
# ----------
# Retriving data for Index 640: Tapes.
# ----------
# Retriving data for Index 641: Brae.
# ----------
# Retriving data for Index 642: Kembe.
# Data missing. Skipping
# ----------
# Retriving data for Index 643: Galle.
# ----------
# Retriving data for Index 644: Alexander City.
# ----------
# Retriving data for Index 645: Tutoia.
# ----------
# Retriving data for Index 646: Kastamonu.
# ----------
# Retriving data for Index 647: Kyabe.
# ----------
# Retriving data for Index 648: Phuket.
# ----------
# Retriving data for Index 649: Kudahuvadhoo.
# ----------
# Retriving data for Index 650: Minden.
# ----------
# Retriving data for Index 651: Soyaux.
# ----------
# Retriving data for Index 652: Paithan.
# ----------
# Retriving data for Index 653: Mentok.
# Data missing. Skipping
# ----------
# Retriving data for Index 654: Wicklow.
# ----------
# Retriving data for Index 655: Thai Nguyen.
# ----------
# Retriving data for Index 656: Pangnirtung.
# ----------
# Retriving data for Index 657: Juneau.
# ----------
# Retriving data for Index 658: Pulandian.
# ----------
# Retriving data for Index 659: Trelleborg.
# ----------
# Retriving data for Index 660: Mana.
# ----------
# Retriving data for Index 661: Osoyoos.
# ----------
# Retriving data for Index 662: Shibetsu.
# ----------
# Retriving data for Index 663: Santa Cruz.
# ----------
# Retriving data for Index 664: Barquisimeto.
# ----------
# Retriving data for Index 665: Faya.
# ----------
# Retriving data for Index 666: Yoichi.
# ----------
# Retriving data for Index 667: Tyrma.
# ----------
# Retriving data for Index 668: Tarko-Sale.
# ----------
# Retriving data for Index 669: Bac Lieu.
# Data missing. Skipping
# ----------
# Retriving data for Index 670: Arequipa.
# ----------
# Retriving data for Index 671: Kyra.
# Data missing. Skipping
# ----------
# Retriving data for Index 672: Yantzaza.
# ----------
# Retriving data for Index 673: Mecca.
# ----------
# Retriving data for Index 674: Ormara.
# ----------
# Retriving data for Index 675: Chenzhou.
# ----------
# Retriving data for Index 676: Mednogorsk.
# ----------
# Retriving data for Index 677: Yegorlykskaya.
# ----------
# Retriving data for Index 678: Pacasmayo.
# ----------
# Retriving data for Index 679: Kargil.
# ----------
# Retriving data for Index 680: Ballangen.
# ----------
# Retriving data for Index 681: Tianpeng.
# ----------
# Retriving data for Index 682: Medicine Hat.
# ----------
# Retriving data for Index 683: Dolbeau.
# Data missing. Skipping
# ----------
# Retriving data for Index 684: Ibirama.
# ----------
# Retriving data for Index 685: Dongsheng.
# ----------
# Retriving data for Index 686: Ranong.
# ----------
# Retriving data for Index 687: Kuusamo.
# ----------
# Retriving data for Index 688: Taltal.
# ----------
# Retriving data for Index 689: Medina.
# ----------
# Retriving data for Index 690: Tevaitoa.
# ----------
# Retriving data for Index 691: Veraval.
# ----------
# Retriving data for Index 692: Den Helder.
# ----------
# Retriving data for Index 693: Black River.
# ----------
# Retriving data for Index 694: Amberley.
# ----------
# Retriving data for Index 695: Bandar-E Torkaman.
# Data missing. Skipping
# ----------
# Retriving data for Index 696: Bolungarvik.
# Data missing. Skipping
# ----------
# Retriving data for Index 697: Zhanatas.
# Data missing. Skipping
# ----------
# Retriving data for Index 698: Dunedin.
# ----------
# Retriving data for Index 699: Markova.
# ----------
# Retriving data for Index 700: Selma.
# ----------
# Retriving data for Index 701: Eenhana.
# ----------
# Retriving data for Index 702: Vestmanna.
# ----------
# Retriving data for Index 703: Terme.
# ----------
# Retriving data for Index 704: Starosubkhangulovo.
# ----------
# Retriving data for Index 705: Quanzhou.
# ----------
# Retriving data for Index 706: Ixtapa.
# ----------
# Retriving data for Index 707: Ulaanbaatar.
# ----------
# Retriving data for Index 708: Truckee.
# ----------
# Retriving data for Index 709: Mandalgovi.
# ----------
# Retriving data for Index 710: Sug-Aksy.
# Data missing. Skipping
# ----------
# Retriving data for Index 711: Rorvik.
# ----------
# Retriving data for Index 712: Ust-Tsilma.
# ----------
# Retriving data for Index 713: Zambezi.
# ----------
# Retriving data for Index 714: Xalpatlahuac.
# ----------
# Retriving data for Index 715: Koutsouras.
# ----------
# Retriving data for Index 716: Shar.
# ----------
# Retriving data for Index 717: Karaul.
# Data missing. Skipping
# ----------
# Retriving data for Index 718: Tocopilla.
# ----------
# Retriving data for Index 719: Kupang.
# ----------
# Retriving data for Index 720: Jiangyou.
# ----------
# Retriving data for Index 721: Grand Forks.
# ----------
# Retriving data for Index 722: Iquique.
# ----------
# Retriving data for Index 723: Lucan.
# ----------

# %%
#Ensure all lists are equal lengths
print(len(cities))
print(len(lat))
print(len(temp))
print(len(humid))
print(len(cloud))
print(len(wind))
# Out:
# 724
# 724
# 724
# 724
# 724
# 724

# %%
# create dataframe
cities_df=pd.DataFrame({'City':cities,
                       'Latitude':lat,
                        'Temperature (F)':temp,
                        'Humidity (%)':humid,
                        'Cloudiness (%)':cloud,
                        "Wind Speed (mph)":wind})
cities_df.head(30)
# Out:
#               City  Latitude  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0     Constitucion     23.99            72.63           8.0            40.0
# 1        Ilulissat     69.22             5.00          60.0            32.0
# 2   Guerrero Negro     27.97            58.56          96.0             0.0
# 3        Rawannawi       NaN              NaN           NaN             NaN
# 4     Punta Arenas    -53.16            46.18          87.0            40.0
# 5         Cherskiy     68.75           -13.17          41.0             0.0
# 6           Atuona     -9.80            82.77         100.0            44.0
# 7             Lebu      8.96            60.80          55.0            75.0
# 8        Upernavik     72.79            -3.54         100.0            32.0
# 9          Mataura    -46.19            57.99          64.0            20.0
# 10       Bathsheba     13.22            78.80          78.0            75.0
# 11        Portland     45.52            51.42          50.0            75.0
# 12         Margate    -43.03            62.76          41.0             0.0
# 13       Busselton    -33.64            63.91          49.0             0.0
# 14          Hasaki     35.73            48.31          34.0            20.0
# 15   Alta Floresta     -9.87            77.64          91.0            36.0
# 16           Airai     -8.93            73.46          86.0            68.0
# 17         Fortuna     38.18            47.79          71.0             0.0
# 18     Port Alfred    -33.59            64.49          93.0            64.0
# 19     Tuktoyaktuk     69.44           -16.61          75.0            75.0
# 20          Albany     42.65            37.89          48.0            90.0
# 21           Kapaa     22.08            77.63          61.0            20.0
# 22          Vanimo     -2.67            82.59          99.0            80.0
# 23   Srednekolymsk     67.46            -1.83          70.0            44.0
# 24            Chuy    -33.69            67.11          92.0            88.0
# 25  Chernyshevskiy     63.01             7.98          72.0            56.0
# 26          Namibe    -15.19            76.74         100.0             0.0
# 27     Lichtenburg    -26.15            58.92          83.0             8.0
# 28       Chlorakas       NaN              NaN           NaN             NaN
# 29         Kavieng     -2.57            81.24         100.0            68.0
#
#     Wind Speed (mph)
# 0              19.46
# 1              13.87
# 2              10.33
# 3                NaN
# 4               5.82
# 5               2.51
# 6              12.46
# 7               4.70
# 8               2.39
# 9               1.99
# 10             12.75
# 11              4.70
# 12             11.41
# 13             14.14
# 14             12.75
# 15              0.94
# 16              0.83
# 17              5.82
# 18              7.87
# 19              6.93
# 20              4.70
# 21             18.34
# 22             17.27
# 23              2.73
# 24             21.07
# 25              2.73
# 26              8.43
# 27              2.84
# 28               NaN
# 29              8.21

# %%
cities_df=cities_df.dropna(how='any')
cities_df.head(30)
# Out:
#               City  Latitude  Temperature (F)  Humidity (%)  Cloudiness (%)  \
# 0     Constitucion     23.99            72.63           8.0            40.0
# 1        Ilulissat     69.22             5.00          60.0            32.0
# 2   Guerrero Negro     27.97            58.56          96.0             0.0
# 4     Punta Arenas    -53.16            46.18          87.0            40.0
# 5         Cherskiy     68.75           -13.17          41.0             0.0
# 6           Atuona     -9.80            82.77         100.0            44.0
# 7             Lebu      8.96            60.80          55.0            75.0
# 8        Upernavik     72.79            -3.54         100.0            32.0
# 9          Mataura    -46.19            57.99          64.0            20.0
# 10       Bathsheba     13.22            78.80          78.0            75.0
# 11        Portland     45.52            51.42          50.0            75.0
# 12         Margate    -43.03            62.76          41.0             0.0
# 13       Busselton    -33.64            63.91          49.0             0.0
# 14          Hasaki     35.73            48.31          34.0            20.0
# 15   Alta Floresta     -9.87            77.64          91.0            36.0
# 16           Airai     -8.93            73.46          86.0            68.0
# 17         Fortuna     38.18            47.79          71.0             0.0
# 18     Port Alfred    -33.59            64.49          93.0            64.0
# 19     Tuktoyaktuk     69.44           -16.61          75.0            75.0
# 20          Albany     42.65            37.89          48.0            90.0
# 21           Kapaa     22.08            77.63          61.0            20.0
# 22          Vanimo     -2.67            82.59          99.0            80.0
# 23   Srednekolymsk     67.46            -1.83          70.0            44.0
# 24            Chuy    -33.69            67.11          92.0            88.0
# 25  Chernyshevskiy     63.01             7.98          72.0            56.0
# 26          Namibe    -15.19            76.74         100.0             0.0
# 27     Lichtenburg    -26.15            58.92          83.0             8.0
# 29         Kavieng     -2.57            81.24         100.0            68.0
# 30         Gravdal     59.79            35.85          93.0            88.0
# 31         Ushuaia    -54.81            51.80          53.0             0.0
#
#     Wind Speed (mph)
# 0              19.46
# 1              13.87
# 2              10.33
# 4               5.82
# 5               2.51
# 6              12.46
# 7               4.70
# 8               2.39
# 9               1.99
# 10             12.75
# 11              4.70
# 12             11.41
# 13             14.14
# 14             12.75
# 15              0.94
# 16              0.83
# 17              5.82
# 18              7.87
# 19              6.93
# 20              4.70
# 21             18.34
# 22             17.27
# 23              2.73
# 24             21.07
# 25              2.73
# 26              8.43
# 27              2.84
# 29              8.21
# 30             14.99
# 31              3.36

# %%
#Export to CSV
cities_df.to_csv(output_file_path)

# %%
#create Temp vs. Latitude Graph
plt.scatter(cities_df['Latitude'],cities_df['Temperature (F)'],c='blue',edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title('Current Temperature vs. Latitude (3/13/19)')
plt.xlim(lat_range)
plt.ylim(0,100)
plt.grid()
plt.show()
tempfilepath=os.path.join('output','temp_vs_lat.png')
plt.savefig(tempfilepath)

# %%
#Create Humidty vs. Latitude graph
plt.scatter(cities_df['Latitude'],cities_df['Humidity (%)'],c='yellow',edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Current Humidity(%) vs. Latitude (3/13/19)')
plt.xlim(lat_range)
plt.ylim(-5,105)
plt.grid()
plt.show()
humidfilepath=os.path.join('output','humid_vs_lat.png')
plt.savefig(humidfilepath)

# %%
#create cloudiness vs. latitude graph
plt.scatter(cities_df['Latitude'],cities_df['Cloudiness (%)'],c='lightblue',edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Current Cloudiness(%) vs. Latitude (3/13/19)')
plt.xlim(lat_range)
plt.ylim(-5,105)
plt.grid()
plt.show()
cloudfilepath=os.path.join('output','cloud_vs_lat.png')
plt.savefig(cloudfilepath)

# %%
#Create Wind Speed vs Lat. Graph
plt.scatter(cities_df['Latitude'],cities_df["Wind Speed (mph)"],c='purple',edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.title('Current Wind Speed vs. Latitude (3/13/19)')
plt.xlim(lat_range)
plt.ylim(0,40)
plt.grid()
plt.show()
windfilepath=os.path.join('output','wind_vs_lat.png')
plt.savefig(windfilepath)

# %% [markdown]
# <h1> Observable Trends </h1>
#
# * Temperature is correlated with Latitude. Cities closer to the equator have a warmer temperature (as we except on a Caribbean vacation!) while cities farther away are cooler. However, cities above the equator are in general cooler than cities on the equal northern latitude.
#
# * Cities that are closer to the equator are overall more humid than cities that are farther away. However, otherwise, there doesn't seem to be huge variation in humidity by latitude. It was raining (or otherwise precipitating) in quite a lot of the sampled cities when this data was taken. Perhaps we are in a rainy season currently.
#
# * Cloudiness and wind speed don't seem to correlate by latitude. However, there are few data points to correspond to the extremes between 40-80 latitude as there are very few land masses and thus cities around that latitude. Perhaps, the winds are similar but our data here doesn't accurately assess those points.
